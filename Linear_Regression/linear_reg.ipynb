# %%
import matplotlib.pyplot as plt
plt.scatter('Temperature','Revenue')

# %%
import pandas as pd
df1=pd.read_csv("Ice_Cream.csv")
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 7.9 KB

# %%
plt.scatter(df1['Temperature'],df1['Revenue'])

# %%
import pandas as pd
df=pd.read_csv("salary.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  501 non-null    float64
#  1   Salary           501 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 8.0 KB

# %%
df.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.956786
# Salary                  0.956786  1.000000

# %%
data=df.corr()
data['Salary']
# Out:
# YearsExperience    0.956786
# Salary             1.000000
# Name: Salary, dtype: float64

# %%
plt.scatter(df['YearsExperience'],df['Salary'])

# %%
from sklearn.linear_model import LinearRegression
x=df[['YearsExperience']]
y=df['Salary']
model=LinearRegression()
model.fit(x,y)          #x as 2D
# Out:
# LinearRegression()

# %%
slope=model.coef_
slope
# Out:
# array([4536.78291734])

# %%
intercept=model.intercept_
intercept
# Out:
# np.float64(24277.664992655773)

# %%
model.predict(x)            #x as 2D
# Out:
# array([ 58303.53687274, 110476.5404222 ,  90514.69558588,  78719.06000079,
#         38341.69203642,  38341.69203642,  29721.80449347, 102764.00946271,
#         78719.06000079,  88699.98241895,  26092.37815959, 112291.25358914,
#         99588.26142057,  43332.1532455 ,  40610.0834951 ,  41063.76178683,
#         51952.04078846,  71913.88562477,  63293.99808182,  50591.00591325,
#         79626.41658426,  36980.65716122,  50591.00591325,  57396.18028927,
#         65562.38954049,  95505.15679496,  42424.79666203,  71006.5290413 ,
#         77811.70341732,  28360.76961827,  79626.41658426,  39702.72691163,
#         30175.4827852 , 110476.5404222 , 111837.5752974 ,  97773.54825363,
#         51952.04078846,  33351.23082734,  86431.59096027,  64201.35466529,
#         35165.94399428,  69191.81587436,  27453.4130348 , 106847.11408832,
#         47868.93616285,  84616.87779334,  52405.71908019,  71460.20733304,
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
df2=pd.read_csv("Placement.csv")
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Year     26 non-null     int64
#  1   cgpa     26 non-null     float64
#  2   package  26 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 756.0 bytes

# %%
plt.scatter(df2['cgpa'],df2['package'])

# %%
df2.corr()
# Out:
#              Year      cgpa   package
# Year     1.000000  0.141867  0.265519
# cgpa     0.141867  1.000000  0.846414
# package  0.265519  0.846414  1.000000

# %%
from sklearn.linear_model import LinearRegression
x=df2[['cgpa']]
y=df2['package']
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
x=df.drop(df['package'],axis=1)
y=df['package']


model.coef_
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'package'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 x=df.drop(df['package'],axis=1)
#       2 y=df['package']
# ...

# %%
model.intercept_
# Out:
# np.float64(-0.9856779462557332)

# %%
model.predict(x)
# Out:
# array([2.93880607, 1.93062948, 3.46852598, 3.24068946, 2.96728564,
#        3.50839737, 2.84767147, 2.85906329, 2.48313304, 3.74762571,
#        2.04454774, 2.77932051, 4.10646823, 2.96158973, 3.41726276,
#        3.14385894, 2.91032651, 2.07872322, 2.96728564, 3.27486494,
#        3.16094668, 2.91602242, 2.5116126 , 2.54009217, 2.73375321,
#        3.16094668, 3.74762571, 2.10150687, 2.39769434, 3.08689981,
#        3.20651398, 3.62801154, 2.97867747, 2.63122678, 3.19512216,
#        2.92741425, 2.42617391, 2.37491069, 3.92419901, 3.24638537,
#        4.3570884 , 2.93880607, 2.40339026, 3.37739137, 1.91354174,
#        3.49700554, 2.47174121, 2.34073522, 3.92989493, 4.06659684,
#        4.47100666, 4.28873744, 3.78180119, 2.69957773, 2.92171834,
#        3.68497067, 2.34073522, 2.7736246 , 2.95589381, 3.32043224,
#        2.20972922, 2.13568235, 2.62553086, 4.23177831, 3.20651398,
#        3.34321589, 1.92493357, 2.72236138, 3.32043224, 3.17233851,
# ...
