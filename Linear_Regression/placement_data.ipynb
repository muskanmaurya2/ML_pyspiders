# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Placement.csv")
x=df[["Year","CGPA"]]
y=df["Package"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.8,random_state=42)

# %%
x_train
# Out:
#     Year  CGPA
# 39  2059   9.4
# 6   2026   6.1
# 25  2045   8.0
# 9   2029   6.2
# 13  2033   6.6
# 31  2051   8.6
# 34  2054   8.9
# 8   2028   6.4
# 17  2037   7.2
# 24  2044   7.9
# 0   2020   5.2
# 33  2053   8.8
# 5   2025   6.0
# 11  2031   6.7
# 1   2021   5.4
# 29  2049   8.4
# 21  2041   7.6
# 2   2022   5.1
# 30  2050   8.5
# 36  2056   9.1
# 3   2023   5.8
# 35  2055   9.0
# 23  2043   7.8
# 32  2052   8.7
# 10  2030   6.5
# 22  2042   7.7
# 18  2038   7.3
# 20  2040   7.5
# 7   2027   6.3
# 14  2034   6.9
# 28  2048   8.3
# 38  2058   9.3

# %%
df.corr()
# Out:
#              Year      CGPA   Package
# Year     1.000000  0.995587  0.991642
# CGPA     0.995587  1.000000  0.991901
# Package  0.991642  0.991901  1.000000

# %%
plt.scatter(df["Year"],df["Package"])

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(x)
# Out:
# array([1.94049931, 2.11639723, 1.96955184, 2.46819306, 2.57954231,
#        2.69089157, 2.80224082, 2.97813874, 3.08948799, 3.00719126,
#        3.24763784, 3.42353575, 3.53488501, 3.45258827, 3.69303485,
#        3.80438411, 3.91573336, 4.02708261, 4.13843187, 4.24978112,
#        4.36113038, 4.47247963, 4.58382888, 4.69517814, 4.80652739,
#        4.91787664, 5.0292259 , 5.14057515, 5.25192441, 5.36327366,
#        5.47462291, 5.58597217, 5.69732142, 5.80867067, 5.92001993,
#        6.03136918, 6.14271844, 6.25406769, 6.36541694, 6.4767662 ])

# %%
y_pred=model.predict(x_train)

# %%
error=y_train-y_pred

# %%
error
# Out:
# 39    0.323234
# 6    -0.002241
# 25   -0.117877
# 9    -0.107191
# 13   -0.352588
# 31   -0.085972
# 34    0.079980
# 8     0.110512
# 17   -0.027083
# 24   -0.306527
# 0     0.159501
# 33    0.091329
# 5     0.209108
# 11   -0.023536
# 1     0.183603
# 29   -0.163274
# 21   -0.072480
# 2     0.030448
# 30    0.125377
# 36   -0.042718
# 3     0.131807
# 35    0.168631
# 23    0.004822
# 32    0.102679
# 10    0.052362
# 22   -0.283829
# 18   -0.038432
# 20   -0.361130
# 7     0.021861
# 14    0.006965
# 28    0.048076
# 38    0.134583
# Name: Package, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, root_mean_squared_error, r2_score

# %%
y_pred_train=model.predict(x_train)
score=r2_score(y_train,y_pred_train)
